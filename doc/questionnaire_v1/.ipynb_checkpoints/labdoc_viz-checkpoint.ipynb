# %%
import pandas as pd 
import mitosheet

# %%
df = pd.read_csv('results-survey171218.csv')

# %%
mitosheet.sheet(analysis_to_replay="id-nrhladyyfq")
# Out:
# MitoWidget(analysis_data_json='{"analysisName": "id-nrhladyyfq", "analysisToReplay": null, "code": [], "stepSu…

# %%
from mitosheet import *; register_analysis("id-nrhladyyfq");
    
# Imported results-survey171218.csv
import pandas as pd
results_survey171218 = pd.read_csv(r'results-survey171218.csv')

# Deleted columns LabDoc 12   , LabDoc 12    [Commentaire]
results_survey171218.drop(['LabDoc 12  \xa0', 'LabDoc 12  \xa0 [Commentaire]'], axis=1, inplace=True)

# Deleted columns Date de soumission, Dernière page, Langue de départ, Tête de série, LabDoc 1, LabDoc 1 [Commentaire], LabDoc 2, LabDoc 2 [Commentaire], LabDoc 3   , LabDoc 3    [Commentaire], LabDoc 4   , LabDoc 4    [Commentaire], LabDoc 5   , LabDoc 5    [Commentaire], LabDoc 6, LabDoc 6 [Commentaire], LabDoc 7, LabDoc 7 [Commentaire], LabDoc 8, LabDoc 8 [Commentaire], LabDoc 9, LabDoc 9 [Commentaire], LabDoc 10   , LabDoc 10    [Commentaire], LabDoc 11   , LabDoc 11    [Commentaire]
results_survey171218.drop(['Date de soumission', 'Dernière page', 'Langue de départ', 'Tête de série', 'LabDoc 1', 'LabDoc 1 [Commentaire]', 'LabDoc 2', 'LabDoc 2 [Commentaire]', 'LabDoc 3  \xa0', 'LabDoc 3  \xa0 [Commentaire]', 'LabDoc 4  \xa0', 'LabDoc 4  \xa0 [Commentaire]', 'LabDoc 5  \xa0', 'LabDoc 5  \xa0 [Commentaire]', 'LabDoc 6', 'LabDoc 6 [Commentaire]', 'LabDoc 7', 'LabDoc 7 [Commentaire]', 'LabDoc 8', 'LabDoc 8 [Commentaire]', 'LabDoc 9', 'LabDoc 9 [Commentaire]', 'LabDoc 10  \xa0', 'LabDoc 10  \xa0 [Commentaire]', 'LabDoc 11  \xa0', 'LabDoc 11  \xa0 [Commentaire]'], axis=1, inplace=True)

# Renamed columns strategie
results_survey171218.rename(columns={'Dans nos travau.. ': 'strategie'}, inplace=True)

# Renamed columns eqc_level
results_survey171218.rename(columns={"L'équilibre de .. ": 'eqc_level'}, inplace=True)

# Renamed columns eqc_val
results_survey171218.rename(columns={"L'équilibre de .. .1": 'eqc_val'}, inplace=True)

# Renamed columns eqc_lev
results_survey171218.rename(columns={'eqc_level': 'eqc_lev'}, inplace=True)

# Renamed columns coec_lev
results_survey171218.rename(columns={'La\xa0co-écriture .. ': 'coec_lev'}, inplace=True)

# Renamed columns eqc_1_lev
results_survey171218.rename(columns={'eqc_lev': 'eqc_1_lev'}, inplace=True)

# Renamed columns eqc_1_val
results_survey171218.rename(columns={'eqc_val': 'eqc_1_val'}, inplace=True)

# Renamed columns coec_1_lev
results_survey171218.rename(columns={'coec_lev': 'coec_1_lev'}, inplace=True)

# Renamed columns coec_1_
results_survey171218.rename(columns={"L'indice de co-.. ": 'coec_1_'}, inplace=True)

# Renamed columns coec_1_val
results_survey171218.rename(columns={'coec_1_': 'coec_1_val'}, inplace=True)

# Renamed columns st_1
results_survey171218.rename(columns={'strategie': 'st_1'}, inplace=True)

# Renamed columns st_2
results_survey171218.rename(columns={'Dans nos travau.. .1': 'st_2'}, inplace=True)

# Renamed columns eqc_2_lev
results_survey171218.rename(columns={"L'équilibre de .. .2": 'eqc_2_lev'}, inplace=True)

# Renamed columns eqc_2_val
results_survey171218.rename(columns={"L'équilibre de .. .3": 'eqc_2_val'}, inplace=True)

# Renamed columns coec_2_lev
results_survey171218.rename(columns={'La\xa0co-écriture .. .1': 'coec_2_lev'}, inplace=True)

# Renamed columns coec_2_val
results_survey171218.rename(columns={"L'indice de co-.. .1": 'coec_2_val'}, inplace=True)

# Renamed columns st_3
results_survey171218.rename(columns={'Dans nos travau.. .2': 'st_3'}, inplace=True)

# Renamed columns eqc_3_lev
results_survey171218.rename(columns={"L'équilibre de .. .4": 'eqc_3_lev'}, inplace=True)

# Renamed columns eqc_3_val
results_survey171218.rename(columns={"L'équilibre de .. .5": 'eqc_3_val'}, inplace=True)

# Renamed columns coec_3_lev
results_survey171218.rename(columns={'La\xa0co-écriture .. .2': 'coec_3_lev'}, inplace=True)

# Renamed columns coec_3_val
results_survey171218.rename(columns={"L'indice de co-.. .2": 'coec_3_val'}, inplace=True)

# Renamed columns st_4
results_survey171218.rename(columns={'Dans nos travau.. .3': 'st_4'}, inplace=True)

# Renamed columns eqc_4_level
results_survey171218.rename(columns={"L'équilibre de .. .6": 'eqc_4_level'}, inplace=True)

# Renamed columns eqc_4_val
results_survey171218.rename(columns={"L'équilibre de .. .7": 'eqc_4_val'}, inplace=True)

# Renamed columns eqc_4_lev
results_survey171218.rename(columns={'eqc_4_level': 'eqc_4_lev'}, inplace=True)

# Renamed columns coec_4_lev
results_survey171218.rename(columns={'La\xa0co-écriture .. .3': 'coec_4_lev'}, inplace=True)

# Renamed columns coec_4_val
results_survey171218.rename(columns={"L'indice de co-.. .3": 'coec_4_val'}, inplace=True)

# Renamed columns st_5
results_survey171218.rename(columns={'Dans nos travau.. .4': 'st_5'}, inplace=True)

# Renamed columns eqc_5_lev
results_survey171218.rename(columns={"L'équilibre de .. .8": 'eqc_5_lev'}, inplace=True)

# Renamed columns eqc_5_val
results_survey171218.rename(columns={"L'équilibre de .. .9": 'eqc_5_val'}, inplace=True)

# Renamed columns coec_5_lev
results_survey171218.rename(columns={'La\xa0co-écriture .. .4': 'coec_5_lev'}, inplace=True)

# Renamed columns coec_5_val
results_survey171218.rename(columns={"L'indice de co-.. .4": 'coec_5_val'}, inplace=True)

# Renamed columns st_6
results_survey171218.rename(columns={'Dans nos travau.. .5': 'st_6'}, inplace=True)

# Renamed columns eqc_6_lev
results_survey171218.rename(columns={"L'équilibre de .. .10": 'eqc_6_lev'}, inplace=True)

# Renamed columns eqc_6_val
results_survey171218.rename(columns={"L'équilibre de .. .11": 'eqc_6_val'}, inplace=True)

# Renamed columns coec_6_lev
results_survey171218.rename(columns={'La\xa0co-écriture .. .5': 'coec_6_lev'}, inplace=True)

# Renamed columns coec_6_val
results_survey171218.rename(columns={"L'indice de co-.. .5": 'coec_6_val'}, inplace=True)

# Renamed columns st_7
results_survey171218.rename(columns={'Dans nos travau.. .6': 'st_7'}, inplace=True)

# Renamed columns eqc_7_lev
results_survey171218.rename(columns={"L'équilibre de .. .12": 'eqc_7_lev'}, inplace=True)

# Renamed columns eqc_7_val
results_survey171218.rename(columns={"L'équilibre de .. .13": 'eqc_7_val'}, inplace=True)

# Renamed columns coec_7_lev
results_survey171218.rename(columns={'La\xa0co-écriture .. .6': 'coec_7_lev'}, inplace=True)

# Renamed columns coec_7_val
results_survey171218.rename(columns={"L'indice de co-.. .6": 'coec_7_val'}, inplace=True)

# Renamed columns st_8
results_survey171218.rename(columns={'Dans nos travau.. .7': 'st_8'}, inplace=True)

# Renamed columns eqc_8_lev
results_survey171218.rename(columns={"L'équilibre de .. .14": 'eqc_8_lev'}, inplace=True)

# Renamed columns eqc_8_val
results_survey171218.rename(columns={"L'équilibre de .. .15": 'eqc_8_val'}, inplace=True)

# Renamed columns coec_8_lev
results_survey171218.rename(columns={'La\xa0co-écriture .. .7': 'coec_8_lev'}, inplace=True)

# Renamed columns L'indice de co-.. .7coe
results_survey171218.rename(columns={"L'indice de co-.. .7": "L'indice de co-.. .7coe"}, inplace=True)

# Renamed columns coec_8_val
results_survey171218.rename(columns={"L'indice de co-.. .7coe": 'coec_8_val'}, inplace=True)

# Renamed columns st_9
results_survey171218.rename(columns={'Dans nos travau.. .8': 'st_9'}, inplace=True)

# Renamed columns eqc_9_lev
results_survey171218.rename(columns={"L'équilibre de .. .16": 'eqc_9_lev'}, inplace=True)

# Renamed columns eqc_9_val
results_survey171218.rename(columns={"L'équilibre de .. .17": 'eqc_9_val'}, inplace=True)

# Renamed columns coec_9_lec
results_survey171218.rename(columns={'La\xa0co-écriture .. .8': 'coec_9_lec'}, inplace=True)

# Renamed columns coec_9_val
results_survey171218.rename(columns={"L'indice de co-.. .8": 'coec_9_val'}, inplace=True)

# Renamed columns st_10
results_survey171218.rename(columns={'Dans nos travau.. .9': 'st_10'}, inplace=True)

# Renamed columns eqc_10_lev
results_survey171218.rename(columns={"L'équilibre de .. .18": 'eqc_10_lev'}, inplace=True)

# Renamed columns eqc_10_val
results_survey171218.rename(columns={"L'équilibre de .. .19": 'eqc_10_val'}, inplace=True)

# Renamed columns coec_10_lev
results_survey171218.rename(columns={'La\xa0co-écriture .. .9': 'coec_10_lev'}, inplace=True)

# Renamed columns coec_10_val
results_survey171218.rename(columns={"L'indice de co-.. .9": 'coec_10_val'}, inplace=True)

# Renamed columns st_11
results_survey171218.rename(columns={'Dans nos travau.. .10': 'st_11'}, inplace=True)

# Renamed columns eqc_11_lev
results_survey171218.rename(columns={"L'équilibre de .. .20": 'eqc_11_lev'}, inplace=True)

# Renamed columns eqc_11_val
results_survey171218.rename(columns={"L'équilibre de .. .21": 'eqc_11_val'}, inplace=True)

# Renamed columns coec_11_lev
results_survey171218.rename(columns={'La\xa0co-écriture .. .10': 'coec_11_lev'}, inplace=True)

# Renamed columns coec_11_val
results_survey171218.rename(columns={"L'indice de co-.. .10": 'coec_11_val'}, inplace=True)

# Renamed columns st_12
results_survey171218.rename(columns={'Dans nos travau.. .11': 'st_12'}, inplace=True)

# Renamed columns eqc_12_lev
results_survey171218.rename(columns={"L'équilibre de .. .22": 'eqc_12_lev'}, inplace=True)

# Renamed columns eqc_12_val
results_survey171218.rename(columns={"L'équilibre de .. .23": 'eqc_12_val'}, inplace=True)

# Renamed columns coec_12_lev
results_survey171218.rename(columns={'La\xa0co-écriture .. .11': 'coec_12_lev'}, inplace=True)

# Renamed columns coec_12_val
results_survey171218.rename(columns={"L'indice de co-.. .11": 'coec_12_val'}, inplace=True)

# Deleted columns Quel est votre .. , Depuis combien .. , Indiquez les mé.. , Avez-vous déja .. , Si vous avez dé.. 
results_survey171218.drop(['Quel est votre .. ', 'Depuis combien .. ', 'Indiquez les mé.. ', 'Avez-vous déja .. ', 'Si vous avez dé.. '], axis=1, inplace=True)

# Renamed columns id_teacher
results_survey171218.rename(columns={'ID de la réponse': 'id_teacher'}, inplace=True)
